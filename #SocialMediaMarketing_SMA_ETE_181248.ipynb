# %% [markdown]
# #### My hashtag for twitter scraping is #SocialMediaMarketing with in July 1st 2019 time limit .For Twitter data we will use Stemming because we will be having more errors because we have to complete in 140 characters.
# #### Here Tweets are not not well written people tend to make more mistakes in tweets.

# %% [markdown]
# ### Load Libraries and import the csv tweets file

# %%
import pandas as pd

# %%
# %cd
# Out:
# C:\Users\MYPC

# %%
# %pwd
# Out:
# 'C:\\Users\\MYPC'

# %%
# %cd C:\Users\MYPC\Downloads\TweetScraper-master\TweetScraper-master
# Out:
# C:\Users\MYPC\Downloads\TweetScraper-master\TweetScraper-master

# %%
df=pd.read_csv("Tweets.csv",sep=",")

# %%
df
# Out:
#                  ID        datetime has_media  is_reply  is_retweet  \
# 0      1.195750e+18  16-11-19 22:49       NaN     False       False
# 1      1.195750e+18  16-11-19 22:49       NaN     False       False
# 2      1.195750e+18  16-11-19 22:50       NaN     False       False
# 3      1.195750e+18  16-11-19 22:50       NaN     False       False
# 4      1.195750e+18  16-11-19 22:50      True     False       False
# 5      1.195750e+18  16-11-19 22:51       NaN     False       False
# 6      1.195750e+18  16-11-19 22:54      True     False       False
# 7      1.195750e+18  16-11-19 22:55       NaN     False       False
# 8      1.195760e+18  16-11-19 22:57       NaN     False       False
# 9      1.195760e+18  16-11-19 22:58       NaN     False       False
# 10     1.195760e+18  16-11-19 23:00       NaN     False       False
# 11     1.195760e+18  16-11-19 23:00       NaN     False       False
# 12     1.195760e+18  16-11-19 23:00      True     False       False
# ...

# %%
df.head()
# Out:
#              ID        datetime has_media  is_reply  is_retweet  \
# 0  1.195750e+18  16-11-19 22:49       NaN     False       False
# 1  1.195750e+18  16-11-19 22:49       NaN     False       False
# 2  1.195750e+18  16-11-19 22:50       NaN     False       False
# 3  1.195750e+18  16-11-19 22:50       NaN     False       False
# 4  1.195750e+18  16-11-19 22:50      True     False       False
#
#                         medias  nbr_favorite  nbr_reply  nbr_retweet  \
# 0                          NaN             3          0            1
# 1                          NaN             0          0            0
# 2                          NaN             0          2            5
# 3                          NaN             1          0            1
# 4  ['https://t.co/NYYzqxk8m7']             0          0            0
#
#                                                 text  \
# 0  The Content Distribution Playbook - Whiteboard...
# 1  # JobAlert  \nCustomer Communications Writer i...
# ...

# %% [markdown]
# ### Performing initial EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23008 entries, 0 to 23007
# Data columns (total 13 columns):
# ID               23008 non-null float64
# datetime         23008 non-null object
# has_media        7287 non-null object
# is_reply         23008 non-null bool
# is_retweet       23008 non-null bool
# medias           7287 non-null object
# nbr_favorite     23008 non-null int64
# nbr_reply        23008 non-null int64
# nbr_retweet      23008 non-null int64
# text             23008 non-null object
# url              23008 non-null object
# user_id          23008 non-null float64
# usernameTweet    23008 non-null object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
df.columns
# Out:
# Index(['ID', 'datetime', 'has_media', 'is_reply', 'is_retweet', 'medias',
#        'nbr_favorite', 'nbr_reply', 'nbr_retweet', 'text', 'url', 'user_id',
#        'usernameTweet'],
#       dtype='object')

# %%
df['medias'].value_counts()
# Out:
# []                             446
# ['https://t.co/vdVit18RPt']    128
# ['https://t.co/SFy9FGQYkT']     62
# ['https://t.co/ZiOiJGVq0I']     33
# ['https://t.co/8BOa5pZZ0R']     25
# ['https://t.co/LSIw5B2Sgn']     23
# ['https://t.co/xSBUqNH0zI']     22
# ['https://t.co/W8jGgbuYHV']     17
# ['https://t.co/Xnihql1en4']     17
# ['https://t.co/wHwqads9FQ']     16
# ['https://t.co/CyWGG4II5l']     16
# ['https://t.co/L4bsVALCxV']     15
# ['https://t.co/NcoeiklTtT']     14
# ['https://t.co/LVZv9EqYKw']     14
# ['https://t.co/2XZeeK07zO']     10
# ['https://t.co/JarC2lvL94']     10
# ['https://t.co/PVz1EJxAE7']     10
# ['https://t.co/iNN7e3bx7r']     10
# ['https://t.co/xYCGkfdglE']     10
# ['https://t.co/23GFk7fLUB']     10
# ['https://t.co/0xwfBpkooY']      9
# ['https://t.co/v963dlwzIo']      9
# ['https://t.co/D9qNhtzR71']      9
# ['https://t.co/l0fUEhAcdP']      9
# ['https://t.co/9DTnpSBlGy']      9
# ['https://t.co/8u1cYB1z9F']      9
# ['https://t.co/fnBDCXpPpm']      9
# ...

# %%
tweets=df
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23008 entries, 0 to 23007
# Data columns (total 13 columns):
# ID               23008 non-null float64
# datetime         23008 non-null object
# has_media        7287 non-null object
# is_reply         23008 non-null bool
# is_retweet       23008 non-null bool
# medias           7287 non-null object
# nbr_favorite     23008 non-null int64
# nbr_reply        23008 non-null int64
# nbr_retweet      23008 non-null int64
# text             23008 non-null object
# url              23008 non-null object
# user_id          23008 non-null float64
# usernameTweet    23008 non-null object
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 2.0+ MB

# %%
tweets['datetime'].value_counts()
# Out:
# 23-11-19 15:04    14
# 27-11-19 21:30    14
# 17-11-19 16:52    14
# 21-11-19 20:06    13
# 29-11-19 3:30     12
# 26-11-19 19:00    12
# 03-12-19 18:00    12
# 20-11-19 2:30     11
# 18-11-19 21:30    11
# 21-11-19 19:00    11
# 26-11-19 11:30    11
# 28-11-19 17:30    11
# 19-11-19 17:48    11
# 20-11-19 23:44    10
# 30-11-19 13:33    10
# 25-11-19 18:00    10
# 27-11-19 19:30    10
# 20-11-19 15:30    10
# 28-11-19 13:33    10
# 25-11-19 21:31    10
# 19-11-19 2:30     10
# 23-11-19 21:00    10
# 27-11-19 19:00    10
# 26-11-19 18:00     9
# 22-11-19 22:30     9
# 23-11-19 6:30      9
# 17-11-19 2:30      9
# 23-11-19 23:40     9
# 26-11-19 10:00     9
# 18-11-19 18:00     9
#                   ..
# 01-12-19 0:03      1
# 18-11-19 23:58     1
# 26-11-19 9:36      1
# 23-11-19 3:15      1
# 27-11-19 8:10      1
# 19-11-19 12:08     1
# 26-11-19 8:46      1
# 17-11-19 3:42      1
# 02-12-19 19:46     1
# 22-11-19 5:57      1
# 23-11-19 0:08      1
# 18-11-19 10:21     1
# ...

# %% [markdown]
# #### 1. Time line of data set
# ### July 1st 2019

# %% [markdown]
# #### 2. Number of tweets in Data set

# %%
len(tweets['text'])
# Out:
# 23008

# %%
tweets.isnull().sum()
# Out:
# ID                   0
# datetime             0
# has_media        15721
# is_reply             0
# is_retweet           0
# medias           15721
# nbr_favorite         0
# nbr_reply            0
# nbr_retweet          0
# text                 0
# url                  0
# user_id              0
# usernameTweet        0
# dtype: int64

# %%
tweets['has_media'].value_counts()
# Out:
# True    7287
# Name: has_media, dtype: int64

# %%
tweets.drop(['has_media','medias'],axis=1)
# Out:
#                  ID        datetime  is_reply  is_retweet  nbr_favorite  \
# 0      1.195750e+18  16-11-19 22:49     False       False             3
# 1      1.195750e+18  16-11-19 22:49     False       False             0
# 2      1.195750e+18  16-11-19 22:50     False       False             0
# 3      1.195750e+18  16-11-19 22:50     False       False             1
# 4      1.195750e+18  16-11-19 22:50     False       False             0
# 5      1.195750e+18  16-11-19 22:51     False       False             0
# 6      1.195750e+18  16-11-19 22:54     False       False             9
# 7      1.195750e+18  16-11-19 22:55     False       False             0
# 8      1.195760e+18  16-11-19 22:57     False       False             1
# 9      1.195760e+18  16-11-19 22:58     False       False             2
# 10     1.195760e+18  16-11-19 23:00     False       False             0
# 11     1.195760e+18  16-11-19 23:00     False       False             3
# ...

# %% [markdown]
# ### Dropping unnecessary columns like id,url,user id,medias...

# %%
x=tweets.drop(['ID','url','user_id','has_media','medias'],axis=1)

# %%
x['len_message']=tweets['text'].apply(lambda x:len(x.split()))

# %%
x.head()
# Out:
#          datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  nbr_retweet  \
# 0  16-11-19 22:49     False       False             3          0            1
# 1  16-11-19 22:49     False       False             0          0            0
# 2  16-11-19 22:50     False       False             0          2            5
# 3  16-11-19 22:50     False       False             1          0            1
# 4  16-11-19 22:50     False       False             0          0            0
#
#                                                 text    usernameTweet  \
# 0  The Content Distribution Playbook - Whiteboard...           Filtr8
# 1  # JobAlert  \nCustomer Communications Writer i...       DLChrist79
# 2  How to create headlines that improve social CT...        iamjony94
# 3  Four Steps To Auditing Your #Business 's #SEO ...  WebTraffic_Tool
# 4  Learn from the top digital marketing experts i...      DMM_Nigeria
#
#    len_message
# 0           20
# 1           19
# 2           30
# ...

# %%
x['len_message'].describe()
# Out:
# count    23008.000000
# mean        24.958406
# std          8.278677
# min          4.000000
# 25%         18.000000
# 50%         25.000000
# 75%         31.000000
# max         67.000000
# Name: len_message, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### To check the messages distributions using this kde plot

# %%
sns.kdeplot(x['len_message']).set_title(" Distribution of Length of Message")
# Out:
# Text(0.5, 1.0, ' Distribution of Length of Message')

# %%
x['text'].value_counts()
# Out:
# Boost your tweets and posts at  http:// Socialater.com    - take a free 14 days trial today #socialmediamarketing                                                                                                                                                                                                                                                                                                                                                                                                                 35
# ...

# %%
x['is_retweet'].value_counts()
# Out:
# False    23008
# Name: is_retweet, dtype: int64

# %%
x['is_retweet']=tweets['text'].apply(lambda x:x[:2]=='RT')
x['is_retweet'].head()  # No of Retweets
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: is_retweet, dtype: bool

# %% [markdown]
# ### Retweet Distribution

# %%
x['is_retweet'].value_counts()
# Out:
# False    22584
# True       424
# Name: is_retweet, dtype: int64

# %% [markdown]
# ### Only 424 retweeted and remaining just tweeted once

# %%
x.head()
# Out:
#          datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  nbr_retweet  \
# 0  16-11-19 22:49     False       False             3          0            1
# 1  16-11-19 22:49     False       False             0          0            0
# 2  16-11-19 22:50     False       False             0          2            5
# 3  16-11-19 22:50     False       False             1          0            1
# 4  16-11-19 22:50     False       False             0          0            0
#
#                                                 text    usernameTweet  \
# 0  The Content Distribution Playbook - Whiteboard...           Filtr8
# 1  # JobAlert  \nCustomer Communications Writer i...       DLChrist79
# 2  How to create headlines that improve social CT...        iamjony94
# 3  Four Steps To Auditing Your #Business 's #SEO ...  WebTraffic_Tool
# 4  Learn from the top digital marketing experts i...      DMM_Nigeria
#
#    len_message
# 0           20
# 1           19
# 2           30
# ...

# %% [markdown]
# #### Likes Distribution through plot

# %%
sns.kdeplot(x['nbr_favorite']).set_title(" Distribution of likes")
# Out:
# Text(0.5, 1.0, ' Distribution of likes')

# %%
sns.kdeplot(x['is_retweet']).set_title(" Distribution of retweet") #GRAPH FOR Distribution of retweet
# Out:
# Text(0.5, 1.0, ' Distribution of retweet')

# %% [markdown]
# ### Hashtags

# %% [markdown]
# ###  To check other  popular Hashtags occured with my  Hashtag SocialMediaMarketing

# %%
def common_hashtags(text):
    retreive=re.sub('#SocialMediaMarketing','',text)
    retreive_new=re.sub('+',' ',retreive)
    return retreive_new

# %%
x['different_tags']=x['hashtags'].apply(lambda x:common_hashtags(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-1de373567d21> in <module>
# ----> 1 x['different_tags']=x['hashtags'].apply(lambda x:common_hashtags(x))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-75-1de373567d21> in <lambda>(x)
# ----> 1 x['different_tags']=x['hashtags'].apply(lambda x:common_hashtags(x))
#
# <ipython-input-60-3e50d03bc236> in common_hashtags(text)
#       1 def common_hashtags(text):
# ----> 2     retreive=re.sub('#SocialMediaMarketing','',text)
# ...

# %%
import re

# %%
def find_hashtags(text):
    '''This function will extract hashtags'''
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', text)

# %%
x['hashtags']=tweets.text.apply(find_hashtags)

# %%
x.head()
# Out:
#          datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  nbr_retweet  \
# 0  16-11-19 22:49     False       False             3          0            1
# 1  16-11-19 22:49     False       False             0          0            0
# 2  16-11-19 22:50     False       False             0          2            5
# 3  16-11-19 22:50     False       False             1          0            1
# 4  16-11-19 22:50     False       False             0          0            0
#
#                                                 text    usernameTweet  \
# 0  The Content Distribution Playbook - Whiteboard...           Filtr8
# 1  # JobAlert  \nCustomer Communications Writer i...       DLChrist79
# 2  How to create headlines that improve social CT...        iamjony94
# 3  Four Steps To Auditing Your #Business 's #SEO ...  WebTraffic_Tool
# 4  Learn from the top digital marketing experts i...      DMM_Nigeria
#
#    len_message                                           hashtags
# ...

# %%
x['hashtags'].describe()
# Out:
# count                       23008
# unique                      10463
# top       [#socialmediamarketing]
# freq                         1491
# Name: hashtags, dtype: object

# %%
# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = x.loc[
                       x.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

# %%
# create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtags'])

# %%
# number of unique hashtags
flattened_hashtags_df['hashtags'].unique().size
# Out:
# 12582

# %%
# count of appearances of each hashtag
popular_hashtags = flattened_hashtags_df.groupby('hashtags').size()\
                                        .reset_index(name='counts')\
                                        .sort_values('counts', ascending=False)\
                                        .reset_index(drop=True)

# %%
import numpy as np

# %%
# number of times each hashtag appears
counts = flattened_hashtags_df.groupby(['hashtags']).size()\
                              .reset_index(name='counts')\
                              .counts

# define bins for histogram                              
my_bins = np.arange(0,counts.max()+400, 400)-0.5

# plot histogram of tweet counts
plt.figure()
plt.hist(counts, bins = my_bins)
plt.xlabels = np.arange(1,counts.max()+400, 400)
plt.xlabel('hashtag number of appearances')
plt.ylabel('frequency')
plt.yscale('log', nonposy='clip')
plt.show()

# %% [markdown]
# ### Date and time of my tweets

# %%
x['datetime']=pd.to_datetime(x['datetime'], errors='coerce')

# %%
x['datetime'].describe()
# Out:
# count                   23008
# unique                  12849
# top       2019-11-23 15:04:00
# freq                       14
# first     2019-01-12 00:00:00
# last      2019-11-30 23:56:00
# Name: datetime, dtype: object

# %%
x['year']=x['datetime'].dt.year

# %%
x.head()
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
x['month']=x['datetime'].dt.month

# %%
x['date']=x['datetime'].dt.date

# %%
x.head()
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
from datetime import date
from datetime import time

# %% [markdown]
# ### Checking my tweets hour wise

# %%
x['hours']=x['datetime'].dt.hour

# %%
x['hours'].value_counts()
# Out:
# 23    1343
# 19    1333
# 22    1264
# 21    1263
# 18    1213
# 20    1206
# 17    1171
# 16    1069
# 0     1067
# 15    1062
# 1     1010
# 2      974
# 13     971
# 3      935
# 14     899
# 12     893
# 11     882
# 10     792
# 5      756
# 6      656
# 4      634
# 9      611
# 7      517
# 8      487
# Name: hours, dtype: int64

# %% [markdown]
# #### Number of tweets in particular hour  by using plot through hourly distribution

# %%
sns.kdeplot(x['hours']).set_title(" Distribution of Number of tweets in particular hour")
# Out:
# Text(0.5, 1.0, ' Distribution of Number of tweets in particular hour')

# %%
x['text'].head()
# Out:
# 0    The Content Distribution Playbook - Whiteboard...
# 1    # JobAlert  \nCustomer Communications Writer i...
# 2    How to create headlines that improve social CT...
# 3    Four Steps To Auditing Your #Business 's #SEO ...
# 4    Learn from the top digital marketing experts i...
# Name: text, dtype: object

# %%
x.head()
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %% [markdown]
# ### Word cloud

# %%
# !pip install wordcloud

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %% [markdown]
# ### Wordcloud for most frequent words

# %%
wordcloud = WordCloud(max_font_size=200, max_words=1000, background_color="white",collocations=False).generate(str(df))
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
wordcloud.to_file("WordCloud_Unigrams_x.png")

# %% [markdown]
# ### Cleaning the text which is tweets

# %%
from nltk.stem.porter import PorterStemmer

# %%
import string
from nltk.corpus import stopwords
from nltk import PorterStemmer as Stemmer

# %%
# DEFING ALL THE FUNCTIONS NEEDED FOR CLEANING THE TEXT
import re # regular expressions
import string # to accept string 
import nltk # it is a text processing libraries for tokenization, parsing, classification, stemming, tagging and semantic reasoning.
from nltk.corpus import stopwords # particular words which are not neccesary in english
from nltk.stem import PorterStemmer# we use stemmer to remove the "ing" of words
def clean_text(text):
    ps=PorterStemmer()
    text1 = re.sub(r'^https?:\/\/.*[\r\n]*', '', text)#remove url
    print(text1)
    text1=re.sub('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)#remove emojis
    print(text1)
    text1=re.sub("\s+"," ",x) # removing the space
    print(text1)
    text1=re.sub('#[\w]+', '', x) # removing 'hastags'
    print(text1)
    text_cleaned=" ".join([x for x in text1 if x not in string.punctuation])# remove punctuations
    print(text_cleaned)
    text_cleaned=text_cleaned.lower() #converting all words upper cases into lower case
    print(text_cleaned)
    text_cleaned=text_cleaned.split(" ")# splitting the words with space if neccessary
    print(text_cleaned)
    text_tokens=[token for token in text_cleaned if token not in STOPWORDS] # Prints list of all tokens in the document
    stem_words=[ps.stem(stem) for stem in text_tokens ] # the stem of all tokens in the document
    text=" ".join(stem_words)
    text_cleaned=re.sub(' +',' ',text)# for removing the extra space
    return text_cleaned

# %%
x['cleaned_text']=x['text'].apply(lambda x:re.sub('http.*','',x)) # removing the URL
x['cleaned_text']=x['cleaned_text'].apply(lambda x:re.sub("\s+"," ",x))# removing the space
x['cleaned_text'].head(5)
# Out:
# 0    The Content Distribution Playbook - Whiteboard...
# 1    # JobAlert Customer Communications Writer in A...
# 2    How to create headlines that improve social CT...
# 3    Four Steps To Auditing Your #Business 's #SEO ...
# 4    Learn from the top digital marketing experts i...
# Name: cleaned_text, dtype: object

# %%
x['cleaned_text'] = x['cleaned_text'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE) ## removing emojis
x['cleaned_text'] = x['cleaned_text'].apply(lambda x:re.sub('#[\w]+', '', x)) # removing '#'
x['cleaned_text'] = x['cleaned_text'].apply(lambda x:re.sub("\s+"," ",x))# removing the space
x['cleaned_text'].head(5)
# Out:
# 0    The Content Distribution Playbook - Whiteboard...
# 1    # JobAlert Customer Communications Writer in A...
# 2    How to create headlines that improve social CT...
# 3                       Four Steps To Auditing Your s
# 4    Learn from the top digital marketing experts i...
# Name: cleaned_text, dtype: object

# %%
x['cleaned_text'].tolist() # to check the reviews
# Out:
# ['The Content Distribution Playbook - Whiteboard Friday ',
#  '# JobAlert Customer Communications Writer in Atlanta GA: ',
#  'How to create headlines that improve social CTR and SEO ',
#  'Four Steps To Auditing Your s ',
#  'Learn from the top digital marketing experts in Nigeria on DMM Nigeria RT @iamjony94 : How to create headlines that improve social CTR and SEO ',
#  'First of all, who cuts pumpkin pie like that Secondly, looks like someone forgot to update the description This isnt the worst Ive seen, but Im curious, whats the worst one youve seen pic.twitter.com/VjQbgUVRlG',
#  '20 Lead Generation Tools to Get More Targeted Leads ',
#  'Worry does nothing but steal joy keep you busy FREE TRAINING that works to generate leads for ANY business ',
#  'FREE FACEBOOK LIVE MASTERCLASS 10 videos 100 % Free Video Course Teaches You How to Dominate Facebook and Get Tons of Leads pic.twitter.com/em6NHSHKsQ',
# ...

# %% [markdown]
# ### Removal of stop words

# %%
STOPWORDS=stopwords.words('english')
print(STOPWORDS)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
x['cleaned_text']=x['cleaned_text'].apply(lambda cleaned_text:"".join([x for x in cleaned_text if x not in string.punctuation]))
# removing punctuations
x['cleaned_text']=x['cleaned_text'].apply(lambda x:x.lower()) # CONVERTING THE UPPERCASE LETTERS TO LOWERCASE
x['cleaned_text'].head(5)
# Out:
# 0    the content distribution playbook  whiteboard ...
# 1     jobalert customer communications writer in at...
# 2    how to create headlines that improve social ct...
# 3                       four steps to auditing your s
# 4    learn from the top digital marketing experts i...
# Name: cleaned_text, dtype: object

# %%
x.head(5)
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
x.sample(n=30)
# Out:
#                  datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 11963 2019-11-25 17:45:00     False        True             0          0
# 22457 2019-03-12 11:21:00     False       False             0          0
# 16186 2019-11-28 12:19:00     False       False             3          0
# 14475 2019-11-27 09:30:00     False       False             1          0
# 3735  2019-11-19 19:32:00     False       False             0          0
# 12271 2019-11-25 21:03:00     False       False             0          0
# 16094 2019-11-28 10:47:00     False       False             0          0
# 19892 2019-01-12 03:34:00     False       False             0          0
# 1281  2019-11-18 05:00:00     False       False             2          0
# 18371 2019-11-29 21:37:00     False       False             2          0
# 21685 2019-02-12 22:07:00     False        True             0          0
# 19462 2019-11-30 20:06:00     False       False             0          0
# ...

# %% [markdown]
# ### Sentiments of the tweets using Vader Package

# %%
from nltk.sentiment import vader
from nltk.sentiment.util import *
import nltk
nltk.download('vader_lexicon')

from nltk import tokenize

sid = vader.SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\MYPC\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
sid = vader.SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score

# %%
def compound_score(text):
    comp=sentiment_analyzer_scores(text)
    return comp['compound'] # returns the compound score from the dictionary

# %%
x['sentiment_score']=x['text'].apply(lambda x:compound_score(x)) # applying on the reviews column to get the score

# %%
x.sample(5)
# Out:
#                  datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 14764 2019-11-27 14:30:00     False       False             4          0
# 170   2019-11-17 01:53:00     False       False             1          0
# 22278 2019-03-12 07:30:00     False       False             3          0
# 19713 2019-11-30 23:45:00     False       False             0          0
# 11927 2019-11-25 17:15:00     False       False             0          0
#
#        nbr_retweet                                               text  \
# 14764            1  Evaluate your strategy over and over again usi...
# 170              0  'How To Use Twitter’s Advanced Search To Drive...
# 22278            0  5 Reasons Your Brand Should be Working With Mi...
# 19713            0  By the way heres my instagram if you wanna fol...
# 11927            0  Branded notebooks are a great way to add some ...
#
#         usernameTweet  len_message  \
# 14764        wpmatovu           41
# ...

# %%
def sentiment_category(score):
    if score >= 0.5:
        return "positive"
    elif score <= -0.5:
        return "negative"
    else:
        return "neutral"

# %%
x['tweet_category']=x['sentiment_score'].apply(lambda x:sentiment_category(x))

# %%
x.sample(5)
# Out:
#                  datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 6253  2019-11-21 05:20:00     False       False             3          1
# 19984 2019-01-12 06:16:00     False       False             1          0
# 11493 2019-11-25 09:52:00     False       False             2          0
# 3881  2019-11-19 21:00:00     False       False             1          0
# 454   2019-11-17 10:59:00     False       False             2          0
#
#        nbr_retweet                                               text  \
# 6253             0  Check out my Blog about Social Media Marketing...
# 19984            1  15 eLearning bundles on sale for 60% off for B...
# 11493            0  Master the @Instagram  and start posting like ...
# 3881             0  Digital Business Mastery: How to Grow Your Ins...
# 454              0  To Succeed in anything you can not do it alone...
#
#          usernameTweet  len_message  \
# 6253   calvinswitzer55           15
# ...

# %%
from collections import Counter

# %%
positive_tweets=x.loc[x['tweet_category']=='positive','cleaned_text'].tolist() # extracting all positive reviews and converting to a list
positive_tweets[0:5]
# Out:
# ['how to create headlines that improve social ctr and seo ',
#  'learn from the top digital marketing experts in nigeria on dmm nigeria rt iamjony94  how to create headlines that improve social ctr and seo ',
#  'worry does nothing but steal joy keep you busy free training that works to generate leads for any business ',
#  'free facebook live masterclass 10 videos 100  free video course teaches you how to dominate facebook and get tons of leads pictwittercomem6nhshksq',
#  'great time at the harrisburgheat scrimmage last night the are looking good this year pictwittercome0uhm0ibdv']

# %%
negative_tweets=x.loc[x['tweet_category']=='negative','cleaned_text'].tolist() # extracting all negative reviews and converting to a list
negative_tweets[0:5]
# Out:
# ['first of all who cuts pumpkin pie like that secondly looks like someone forgot to update the description this isnt the worst ive seen but im curious whats the worst one youve seen pictwittercomvjqbguvrlg',
#  'email marketing its the audience stupid ',
#  'have a bad reputation own it ',
#  '15 ways to fail at  bragging  being antisocial  being inconsistent  providing useless  not taking seriously   via fklivestolearn piktochart pictwittercom7qdhrmmnm0',
#  '15 ways to fail at  bragging  being antisocial  being inconsistent  providing useless  not taking seriously   via fklivestolearn piktochart ']

# %%
x['text']=x['text'].apply(lambda x:x.strip('\n'))   ### To remove spaces from every tweets like \n

# %%
x.head()
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
def getMostCommon(tweets_list,topn=20):
    tweets=" ".join(tweets_list)
    tokenised_tweets=tweets.split(" ")
    
    
    freq_counter=Counter(tokenised_tweets)
    return freq_counter.most_common(topn) # return words with the highest frequencies

# %%
from collections import Counter

# %%
def getMostCommon(tweets_list,topn=20):
    tweets=" ".join(tweets_list)
    tokenised_tweets=tweets.split(" ")
    
    
    freq_counter=Counter(tokenised_tweets)
    return freq_counter.most_common(topn) # return words with the highest frequencies

# %% [markdown]
# ### Unigrams - Individual words in my tweets

# %%
top_20_positive_tweet_words=getMostCommon(positive_tweets,20)

# %%
top_20_positive_tweet_words
# Out:
# [('', 8272),
#  ('to', 5291),
#  ('the', 3822),
#  ('your', 3814),
#  ('and', 3017),
#  ('you', 2971),
#  ('a', 2461),
#  ('for', 2403),
#  ('social', 2099),
#  ('of', 2015),
#  ('media', 1876),
#  ('on', 1700),
#  ('is', 1535),
#  ('with', 1451),
#  ('in', 1412),
#  ('marketing', 1394),
#  ('how', 1071),
#  ('business', 1028),
#  ('best', 992),
#  ('are', 953)]

# %%
top_20_negative_tweet_words=getMostCommon(negative_tweets,20)

# %%
top_20_negative_tweet_words
# Out:
# [('', 478),
#  ('to', 212),
#  ('the', 180),
#  ('you', 140),
#  ('a', 121),
#  ('and', 97),
#  ('is', 94),
#  ('of', 89),
#  ('your', 89),
#  ('social', 87),
#  ('media', 81),
#  ('it', 77),
#  ('marketing', 75),
#  ('on', 73),
#  ('for', 69),
#  ('how', 68),
#  ('not', 61),
#  ('in', 61),
#  ('that', 50),
#  ('its', 47)]

# %%
def plotMostCommonWords(tweets_list,topn=20,title="Common tweet Words",color="blue",axis=None): #default number of words is given as 20
    top_words=getMostCommon(tweets_list,topn=topn)
    data=pd.DataFrame()
    data['words']=[val[0] for val in top_words]
    data['freq']=[val[1] for val in top_words]
    if axis!=None:
        sns.barplot(y='words',x='freq',data=data,color=color,ax=axis).set_title(title+" top "+str(topn))
    else:
        sns.barplot(y='words',x='freq',data=data,color=color).set_title(title+" top "+str(topn))

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 8,6 ## Sets the heigth and width of image


fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=0.5) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets,20,"Positive tweet Unigrams",axis=ax[0])

plotMostCommonWords(negative_tweets,20,"Negative tweet Unigrams",color="red",axis=ax[1])

# %% [markdown]
# ### Bigrams - Two words in my tweets

# %%
def generateNGram(text,n):
    tokens=text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_bigrams=[" ".join(generateNGram(tweet,2)) for tweet in positive_tweets]
negative_tweets_bigrams=[" ".join(generateNGram(tweet,2)) for tweet in negative_tweets]

# %%
positive_tweets_bigrams[:5]
# Out:
# ['how_to to_create create_headlines headlines_that that_improve improve_social social_ctr ctr_and and_seo seo_',
#  'learn_from from_the the_top top_digital digital_marketing marketing_experts experts_in in_nigeria nigeria_on on_dmm dmm_nigeria nigeria_rt rt_iamjony94 iamjony94_ _how how_to to_create create_headlines headlines_that that_improve improve_social social_ctr ctr_and and_seo seo_',
#  'worry_does does_nothing nothing_but but_steal steal_joy joy_keep keep_you you_busy busy_free free_training training_that that_works works_to to_generate generate_leads leads_for for_any any_business business_',
#  'free_facebook facebook_live live_masterclass masterclass_10 10_videos videos_100 100_ _free free_video video_course course_teaches teaches_you you_how how_to to_dominate dominate_facebook facebook_and and_get get_tons tons_of of_leads leads_pictwittercomem6nhshksq',
# ...

# %%
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1)
plotMostCommonWords(positive_tweets_bigrams,40,"Positive tweet Bigrams",axis=ax[0])

plotMostCommonWords(negative_tweets_bigrams,40,"Negative tweet Bigrams",color="red",axis=ax[1])

# %% [markdown]
# ## Trigrams - Three Words in my tweets

# %%
def generateNGram(text,n):
    tokens=text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_trigrams=[" ".join(generateNGram(tweet,3)) for tweet in positive_tweets]
negative_tweets_trigrams=[" ".join(generateNGram(tweet,3)) for tweet in negative_tweets]

# %%
positive_tweets_trigrams[:5]
# Out:
# ['how_to_create to_create_headlines create_headlines_that headlines_that_improve that_improve_social improve_social_ctr social_ctr_and ctr_and_seo and_seo_',
#  'learn_from_the from_the_top the_top_digital top_digital_marketing digital_marketing_experts marketing_experts_in experts_in_nigeria in_nigeria_on nigeria_on_dmm on_dmm_nigeria dmm_nigeria_rt nigeria_rt_iamjony94 rt_iamjony94_ iamjony94__how _how_to how_to_create to_create_headlines create_headlines_that headlines_that_improve that_improve_social improve_social_ctr social_ctr_and ctr_and_seo and_seo_',
#  'worry_does_nothing does_nothing_but nothing_but_steal but_steal_joy steal_joy_keep joy_keep_you keep_you_busy you_busy_free busy_free_training free_training_that training_that_works that_works_to works_to_generate to_generate_leads generate_leads_for leads_for_any for_any_business any_business_',
# ...

# %%
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1)
plotMostCommonWords(positive_tweets_trigrams,40,"Positive tweet Trigrams",axis=ax[0])

plotMostCommonWords(negative_tweets_trigrams,40,"Negative tweet Trigrams",color="red",axis=ax[1])

# %% [markdown]
# ### More than 3 words that is 4 or  more words in my tweets .

# %%
def generateNGram(cleaned_text,n=4):
    tokens=cleaned_text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
positive_tweets_moregrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in positive_tweets]
negative_tweets_moregrams=[" ".join(generateNGram(cleaned_text)) for cleaned_text in negative_tweets]

# %%
top_20_positive_moregrams=getMostCommon(positive_tweets_moregrams,topn=20)
top_20_positive_moregrams=getMostCommon(positive_tweets_moregrams,topn=20)

# %%
rcParams['figure.figsize'] = 15,20
fig,ax=plt.subplots(1,2)
fig.subplots_adjust(wspace=1) #Adjusts the space between the two plots
plotMostCommonWords(positive_tweets_moregrams,50,"Positive Tweets moregrams",axis=ax[0])

plotMostCommonWords(negative_tweets_moregrams,50,"Negative Tweets moregrams",color="red",axis=ax[1])

# %% [markdown]
# ### Most common words in the Tweets are build in a word cloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(x['cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common tweets")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Positive words in the tweets are build in a word cloud

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(x.loc[x['sentiment']=='positive','cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Positive words for Tweets")#positive tweets
plt.axis('off')
plt.show()

# %% [markdown]
# ### Negative words in the tweets are build in a wordcoud

# %%
wordcloud = WordCloud(height=2000, width=2000,stopwords=set(stopwords.words('english')), background_color='white')
wordcloud = wordcloud.generate(' '.join(x.loc[x['sentiment']=='negative','cleaned_text'].tolist()))
plt.imshow(wordcloud)
plt.title("Negative words for Tweets")#negative tweets
plt.axis('off')
plt.show()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
x['sentiment_compound_polarity']=x['text'].apply(lambda x:sid.polarity_scores(x)['compound'])
x['sentiment_negative']=x['text'].apply(lambda x:sid.polarity_scores(x)['neg'])
x['sentiment_pos']=x['text'].apply(lambda x:sid.polarity_scores(x)['pos'])
x['sentiment']=''
x.loc[x.sentiment_compound_polarity>=0,'sentiment']="positive"
x.loc[x.sentiment_compound_polarity==0,'sentiment']="neutral"

x.loc[x.sentiment_compound_polarity<0,'sentiment']="negative"
sid = vader.SentimentIntensityAnalyzer()

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    #print(score)
    return score

# %%
def compound_score(text):
    sc=sentiment_analyzer_scores(text) ### Calculates compound scores of the tweets 
    return sc['compound']

# %%
x['comp_score']=x['cleaned_text'].apply(lambda x:compound_score(x))

# %%
x.head(5)
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
# GRAPHICAL REPRESENTATION OF comp_score Distribution 
sns.kdeplot(x['comp_score']).set_title(" Distribution of comp_score")
# Out:
# Text(0.5, 1.0, ' Distribution of comp_score')

# %%
x.head()
# Out:
#              datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 0 2019-11-16 22:49:00     False       False             3          0
# 1 2019-11-16 22:49:00     False       False             0          0
# 2 2019-11-16 22:50:00     False       False             0          2
# 3 2019-11-16 22:50:00     False       False             1          0
# 4 2019-11-16 22:50:00     False       False             0          0
#
#    nbr_retweet                                               text  \
# 0            1  The Content Distribution Playbook - Whiteboard...
# 1            0  # JobAlert  \nCustomer Communications Writer i...
# 2            5  How to create headlines that improve social CT...
# 3            1  Four Steps To Auditing Your #Business 's #SEO ...
# 4            0  Learn from the top digital marketing experts i...
#
#      usernameTweet  len_message  \
# 0           Filtr8           20
# 1       DLChrist79           19
# 2        iamjony94           30
# ...

# %%
x['sentiment'].value_counts()
# Out:
# positive    13473
# neutral      7920
# negative     1615
# Name: sentiment, dtype: int64

# %% [markdown]
# ### Value_counts gives the number of positive,negative and neutral sentiments

# %% [markdown]
# #### Positive,negative and neutral tweets Distribution  based on hours

# %%
sns.kdeplot(x.loc[x['sentiment']=="positive","hours"],label='positive');
sns.kdeplot(x.loc[x['sentiment']=="negative","hours"],label='negative');
sns.kdeplot(x.loc[x['sentiment']=="neutral","hours"],label='neutral');

###Beautification of labels
plt.xlabel('Hour of the day')
plt.ylabel('Density')
plt.show()

### This plot shows the Hourly tweets distribution of positive ,negative and neutral

# %%
sns.countplot(x['sentiment'])

# %%
x[x['sentiment']=="negative"].head()
# Out:
#               datetime  is_reply  is_retweet  nbr_favorite  nbr_reply  \
# 5  2019-11-16 22:51:00     False       False             0          0
# 14 2019-11-16 23:03:00     False       False             1          0
# 16 2019-11-16 23:03:00     False       False             0          0
# 31 2019-11-16 23:15:00     False       False             0          0
# 37 2019-11-16 23:20:00     False       False             0          0
#
#     nbr_retweet                                               text  \
# 5             0  First of all, who cuts pumpkin pie like that?\...
# 14            0  TikTok teases social commerce capabilities wit...
# 16            0  The average consumer today is exposed to about...
# 31            0  Don't lose hope you never know what tomorrow w...
# 37            0  What To Do When Someone Tells You You're Not G...
#
#       usernameTweet  len_message  \
# 5   _MariaMarchewka           36
# 14           Filtr8           21
# 16     ensettdotcom           25
# ...

# %% [markdown]
# ###  Clustering the tweets - Topic Modelling

# %%
 ## Data manipulation
import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.max_colwidth=-1

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from IPython import get_ipython
ipython = get_ipython()
# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload

# %autoreload 2

# Visualizations
# !pip install plotly
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import re

import gensim
from gensim import corpora

# libraries for visualization
# !pip install pyLDAvis
import pyLDAvis
import pyLDAvis.gensim

# %%
import string
def removePunct(text):
    text = text.translate(str.maketrans({key: " {0} ".format(key) for key in string.punctuation}))
    
    text_cleaned="".join([x for x in text if x not in string.punctuation])
    text_cleaned=re.sub(r'[^\x00-\x7F]+',' ', text_cleaned) ## Remove Ascii Characters
    text_cleaned=re.sub('\s+', ' ', text_cleaned).strip()
    return text_cleaned
# Out:
# <>:7: DeprecationWarning:
#
# invalid escape sequence \s
#
# <>:7: DeprecationWarning:
#
# invalid escape sequence \s
#
# <>:7: DeprecationWarning:
#
# invalid escape sequence \s
#
# <ipython-input-155-7d387e9263d6>:7: DeprecationWarning:
#
# invalid escape sequence \s

# %%
x=x[~pd.isnull(x['text'])]
x.shape
# Out:
# (23008, 22)

# %%
corpus=x['text'].tolist()

# %%
corpus
# Out:
# ['The Content Distribution Playbook - Whiteboard Friday #marketing  #contentmarketing  #inboundmarketing  #blog  #mktg  #socialmedia  #socialmediamarketing  #smm  #growthhacking  #website   https:// buff.ly/33Pfc8J \xa0 pic.twitter.com/1LUlv3WNJC',
#  '# JobAlert  \nCustomer Communications Writer in Atlanta GA:\n https:// kforce.workllama.com/atsuser/referr al/71q6Ow \xa0 … \n\n#digital  #writingcommmunity  #communications  #socialmediamarketing  #Creative  \n#technology  #databasemanagement',
#  'How to create headlines that improve social CTR and SEO  http:// ow.ly/bick30k7HRI \xa0  #socialmedia  #socialmediamarketing  #digitalmarketing  #contentmarketing  #growthhacking  #startup  #SEO  #SMM  #ecommerce  #marketing  #blogging  #infographic  #deeplearning  #ai  #bigdata  #datascience  #fintech pic.twitter.com/jJAgvRxh5f',
# ...

# %%
tokenised_corpus=[]
for corp in corpus:
    
    tokenised_corpus.append([token for token in corp.split(" ")])
tokenised_corpus
# Out:
# [['The',
#   'Content',
#   'Distribution',
#   'Playbook',
#   '-',
#   'Whiteboard',
#   'Friday',
#   '#marketing',
#   '',
#   '#contentmarketing',
#   '',
#   '#inboundmarketing',
#   '',
#   '#blog',
#   '',
#   '#mktg',
#   '',
#   '#socialmedia',
#   '',
#   '#socialmediamarketing',
#   '',
#   '#smm',
#   '',
#   '#growthhacking',
#   '',
#   '#website',
#   '',
#   '',
#   'https://',
#   'buff.ly/33Pfc8J',
#   '\xa0',
#   'pic.twitter.com/1LUlv3WNJC'],
#  ['#',
#   'JobAlert',
#   '',
#   '\nCustomer',
#   'Communications',
#   'Writer',
#   'in',
#   'Atlanta',
#   'GA:\n',
#   'https://',
#   'kforce.workllama.com/atsuser/referr',
#   'al/71q6Ow',
#   '\xa0',
#   '…',
#   '\n\n#digital',
#   '',
#   '#writingcommmunity',
#   '',
#   '#communications',
#   '',
#   '#socialmediamarketing',
#   '',
#   '#Creative',
#   '',
#   '\n#technology',
#   '',
#   '#databasemanagement'],
#  ['How',
#   'to',
#   'create',
#   'headlines',
#   'that',
#   'improve',
#   'social',
# ...

# %%
dictionary = corpora.Dictionary(tokenised_corpus)

# %%
len(dictionary)
# Out:
# 76762

# %%
doc_term_matrix = [dictionary.doc2bow(rev) for rev in tokenised_corpus]

# %%
doc_term_matrix[3]
# Out:
# [(0, 13),
#  (2, 1),
#  (7, 1),
#  (9, 1),
#  (19, 1),
#  (21, 1),
#  (39, 1),
#  (64, 1),
#  (65, 1),
#  (66, 1),
#  (67, 1),
#  (68, 1),
#  (69, 1),
#  (70, 1),
#  (71, 1),
#  (72, 1),
#  (73, 1),
#  (74, 1),
#  (75, 1),
#  (76, 1),
#  (77, 1),
#  (78, 1)]

# %%
LDA = gensim.models.ldamodel.LdaModel

# Build LDA model
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=4, random_state=100,
                chunksize=100, passes=50)

# %%
lda_model.print_topics()

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis

# %%
vectorizer = TfidfVectorizer()
tfidf_model = vectorizer.fit_transform(tweets)

# %%
tfidf = pd.DataFrame(tfidf_model.toarray(), columns = vectorizer.get_feature_names())
tfidf

# %%
print(vectorizer.get_feature_names())

# %%
def getMostCommon(reviews_list,topn=20):
    reviews=" ".join(reviews_list)
    tokenised_reviews=reviews.split(" ")
    
    
    freq_counter=Counter(tokenised_reviews)
    return freq_counter.most_common(topn)

# %%
from collections import Counter

# %%
def generateNGram(text,n=2):
    tokens=text.split(" ")
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return ["_".join(ngram) for ngram in ngrams]

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

# %%
lda_model[doc_term_matrix[1]]

# %%
lda_model.show_topic(3)

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=doc_term_matrix, texts=corpus)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)

# %%
lda_model.log_perplexity(doc_term_matrix)

# %%
from gensim.models import CoherenceModel

coherence_model_lda = CoherenceModel(model=lda_model, texts=tokenised_corpus, dictionary=dictionary,coherence="c_v")
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=num_topics, random_state=100,chunksize=1000, passes=50)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=tokenised_corpus, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        print(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=doc_term_matrix, texts=tokenised_corpus, start=2, limit=10, step=2)

# %%
limit=10
start=2
step=2
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)

# %%
from sklearn.feature_extraction.text import CountVectorizer
